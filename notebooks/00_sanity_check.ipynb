# %% [markdown]
# # 00_sanity_check
#
# Purpose:
# - Verify Qiskit + Jupyter setup
# - Confirm basic circuit execution
# - Serve as a baseline environment check

# %%
"""
00_sanity_check.ipynb

Purpose:
- Verify that Qiskit and Jupyter are installed correctly
- Confirm basic imports and version information
- Serve as a baseline environment check before building algorithms
"""

import sys
import qiskit

print("Python version:")
print(sys.version)

print("\nQiskit version:")
print(qiskit.__version__)
# Out:
# Python version:
# 3.12.4 | packaged by Anaconda, Inc. | (main, Jun 18 2024, 10:07:17) [Clang 14.0.6 ]
#
# Qiskit version:
# 1.1.0
